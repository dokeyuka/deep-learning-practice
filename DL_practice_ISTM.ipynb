# %% [markdown]
# <a href="https://colab.research.google.com/github/dokeyuka/deep-learning-practice/blob/main/DL_practice_ISTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LSTM
# ## ＲＮＮの長期の依存性による勾配の消失を解消
# ## 1 CEC/入力/出力ゲートの導入
# ## 2 忘却ゲートの導入
# ## 3 覗き穴結合の導入

# %%
import numpy as np

def sin(x, T = 100):
  return np.sin(2.0*np.pi*x/T)

def toy_problem(T = 100, ampl = 0.05):
  x = np.arange(0, 2*T+1)
  noise = ampl*np.random.uniform(low = -1.0, high = 1.0, size = len(x))
  return sin(x)+noise

T = 100
f = toy_problem(T).astype(np.float32)
print(f.shape)

length_of_sequences = len(f)#2T+1
# Out:
# (201,)

# %%
import torch.nn as nn
import torch.nn.functional as F
import torch
import os
import numpy as np
from sklearn.metrics import accuracy_score
import torch.optim as optimizers
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torch.utils.data import random_split
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

class EarlyStopping:
  def __init__(self, patience = 0, verbose = 0):
    #self._step 連続で最小値を上回ったepoch数を保持
    self._step = 0
    #self._loss 誤差の最小値を保持
    self._loss = float('inf')
    self.patience = patience
    self.verbose = verbose
  
  def __call__(self, loss):
    if self._loss < loss:
      self._step += 1
      if self._step > self.patience:
        if self.verbose:
          print('early stopping')
          return True
    else:
        self._step = 0
        self._loss = loss
    return False  



class RNN(nn.Module):
  def __init__(self, hidden_dim):
    super().__init__()
    # batch_first = Trueで(データ数N,　時系列長tau,　入力次元l)の順にデータを与える
    self.l1 = nn.LSTM(1, hidden_dim, 
                     batch_first = True)
    
    self.l2 = nn.Linear(hidden_dim, 1)
    
    nn.init.xavier_normal_(self.l1.weight_ih_l0)#入力層-隠れ層(input-hidden)の重みの初期化,l0:一つ目の隠れ層
    nn.init.orthogonal_(self.l1.weight_hh_l0)#隠れ層-隠れ層(hidden-hidden)の重みの初期化

  def forward(self, x):
    #戻り値(各時刻における隠れ層の出力、隠れ層の値)
    h, _ = self.l1(x)
    #出力層には最後の時刻の隠れ層の出力を与える
    y = self.l2(h[:,-1])

    return y




if __name__ == '__main__':
  np.random.seed(123)
  #torch用の乱数シード
  torch.manual_seed(123)

  #deviceに実行環境を格納して同じコードでCPUでもGPUでも対応できるように
  device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

'''
  1 データの準備
'''
maxlen = 25
x = []
t = []
for i in range(length_of_sequences-maxlen):
  x.append(f[i:i+maxlen])
  t.append(f[i+maxlen])

x = np.array(x).reshape(-1,maxlen,1)
t = np.array(t).reshape(-1,1)

#時系列順にするためshuffle = False
x_train, x_val, t_train, t_val = train_test_split(x,t,test_size = 0.2, shuffle = False)



'''
2 modelの構築
'''
#隠れ層の次元50
model = RNN(50).to(device)

'''
3 modelの学習
'''
#平均2乗誤差(ばっちごとの平均なのでreduction = mean)
criterion = nn.MSELoss(reduction = 'mean')
optimizer = optimizers.Adam(model.parameters(),
                            lr = 0.0005,
                            betas = (0.9,0.999),
                            amsgrad = True)
def compute_loss(t,y):
  return criterion(y, t)

def train_step(x,t):
  x = torch.Tensor(x).to(device)
  t = torch.Tensor(t).to(device)
  model.train()
  preds = model(x)
  loss = compute_loss(t, preds)
  optimizer.zero_grad()
  loss.backward()
  optimizer.step()
  return loss, preds

def val_step(x,t):
  x = torch.Tensor(x).to(device)
  t = torch.Tensor(t).to(device)
  model.eval()
  preds = model(x)
  loss = criterion(preds,t)
  return loss, preds

epochs = 1000
batch_size = 100
n_batches_train = x_train.shape[0]//batch_size +1
print(n_batches_train)
n_batches_val = x_val.shape[0]//batch_size + 1
hist = {'loss':[], 'val_loss':[]}
es = EarlyStopping(patience = 10, verbose = 1)

for epoch in range(epochs):
  train_loss = 0.
  val_loss = 0.
  x_, t_ = shuffle(x_train, t_train) 

  for batch in range(n_batches_train):
    start = batch*batch_size
    end = start + batch_size
    loss, _ = train_step(x_[start:end], t_[start:end])
    train_loss += loss.item()

  for batch in range(n_batches_val):
    start = batch*batch_size
    end = start + batch_size
    loss, _ = val_step(x_val[start:end], t_val[start:end])
    val_loss += loss.item()

  train_loss /= n_batches_train
  val_loss /= n_batches_val

  hist['loss'].append(train_loss)
  hist['val_loss'].append(val_loss)

  print('epoch:{}, loss:{:.3}, val_loss:{:.3f}'.format(
      epoch+1,
      train_loss,
      val_loss
  ))

  if es(val_loss):
    break


'''
  4 モデルの評価
'''
model.eval()

#sin波の予測
sin_wave = toy_problem(T, ampl = 0.)
gen = [None for i in range(maxlen)]
z = x[:1]

for i in range(length_of_sequences - maxlen):
  z_ = torch.Tensor(z[-1:]).to(device)
  preds = model(z_).data.cpu().numpy()
  z = np.append(z, preds)[1:]
  z = z.reshape(-1, maxlen, 1)
  gen.append(preds[0,0])
# Out:
# 2
# epoch:1, loss:0.463, val_loss:0.663
# epoch:2, loss:0.443, val_loss:0.649
# epoch:3, loss:0.435, val_loss:0.637
# epoch:4, loss:0.419, val_loss:0.626
# epoch:5, loss:0.412, val_loss:0.616
# epoch:6, loss:0.391, val_loss:0.604
# epoch:7, loss:0.428, val_loss:0.594
# epoch:8, loss:0.394, val_loss:0.581
# epoch:9, loss:0.387, val_loss:0.567
# epoch:10, loss:0.369, val_loss:0.551
# epoch:11, loss:0.398, val_loss:0.536
# epoch:12, loss:0.376, val_loss:0.521
# epoch:13, loss:0.372, val_loss:0.504
# epoch:14, loss:0.347, val_loss:0.485
# epoch:15, loss:0.332, val_loss:0.464
# epoch:16, loss:0.322, val_loss:0.441
# epoch:17, loss:0.31, val_loss:0.417
# epoch:18, loss:0.31, val_loss:0.392
# epoch:19, loss:0.28, val_loss:0.365
# epoch:20, loss:0.273, val_loss:0.333
# epoch:21, loss:0.252, val_loss:0.298
# epoch:22, loss:0.228, val_loss:0.260
# epoch:23, loss:0.216, val_loss:0.218
# epoch:24, loss:0.196, val_loss:0.176
# epoch:25, loss:0.171, val_loss:0.135
# epoch:26, loss:0.153, val_loss:0.100
# epoch:27, loss:0.13, val_loss:0.080
# epoch:28, loss:0.12, val_loss:0.076
# epoch:29, loss:0.12, val_loss:0.076
# epoch:30, loss:0.115, val_loss:0.075
# epoch:31, loss:0.115, val_loss:0.072
# epoch:32, loss:0.103, val_loss:0.068
# epoch:33, loss:0.0977, val_loss:0.066
# epoch:34, loss:0.0987, val_loss:0.064
# epoch:35, loss:0.0892, val_loss:0.063
# epoch:36, loss:0.0868, val_loss:0.061
# epoch:37, loss:0.0831, val_loss:0.058
# epoch:38, loss:0.0805, val_loss:0.055
# epoch:39, loss:0.0715, val_loss:0.053
# epoch:40, loss:0.0735, val_loss:0.050
# epoch:41, loss:0.0672, val_loss:0.048
# epoch:42, loss:0.0609, val_loss:0.046
# epoch:43, loss:0.0597, val_loss:0.044
# epoch:44, loss:0.0539, val_loss:0.041
# epoch:45, loss:0.0539, val_loss:0.039
# epoch:46, loss:0.0489, val_loss:0.037
# epoch:47, loss:0.0462, val_loss:0.035
# epoch:48, loss:0.045, val_loss:0.033
# epoch:49, loss:0.0432, val_loss:0.031
# epoch:50, loss:0.034, val_loss:0.029
# epoch:51, loss:0.0299, val_loss:0.028
# epoch:52, loss:0.0254, val_loss:0.026
# epoch:53, loss:0.0257, val_loss:0.024
# epoch:54, loss:0.0197, val_loss:0.022
# epoch:55, loss:0.0188, val_loss:0.019
# epoch:56, loss:0.0148, val_loss:0.017
# epoch:57, loss:0.0121, val_loss:0.015
# epoch:58, loss:0.00868, val_loss:0.013
# epoch:59, loss:0.00708, val_loss:0.011
# epoch:60, loss:0.00609, val_loss:0.010
# epoch:61, loss:0.00563, val_loss:0.009
# epoch:62, loss:0.00453, val_loss:0.008
# epoch:63, loss:0.00436, val_loss:0.007
# epoch:64, loss:0.00389, val_loss:0.005
# epoch:65, loss:0.0034, val_loss:0.004
# epoch:66, loss:0.00277, val_loss:0.004
# epoch:67, loss:0.00228, val_loss:0.004
# epoch:68, loss:0.00243, val_loss:0.004
# epoch:69, loss:0.00238, val_loss:0.004
# epoch:70, loss:0.00249, val_loss:0.004
# epoch:71, loss:0.0026, val_loss:0.003
# epoch:72, loss:0.00244, val_loss:0.003
# epoch:73, loss:0.00265, val_loss:0.003
# epoch:74, loss:0.00245, val_loss:0.003
# epoch:75, loss:0.00238, val_loss:0.003
# epoch:76, loss:0.00213, val_loss:0.003
# epoch:77, loss:0.00195, val_loss:0.003
# epoch:78, loss:0.00199, val_loss:0.003
# epoch:79, loss:0.00222, val_loss:0.003
# epoch:80, loss:0.00196, val_loss:0.003
# epoch:81, loss:0.0022, val_loss:0.003
# epoch:82, loss:0.00182, val_loss:0.003
# epoch:83, loss:0.00209, val_loss:0.003
# epoch:84, loss:0.00187, val_loss:0.003
# epoch:85, loss:0.00191, val_loss:0.003
# epoch:86, loss:0.0017, val_loss:0.003
# epoch:87, loss:0.00182, val_loss:0.003
# epoch:88, loss:0.00216, val_loss:0.003
# epoch:89, loss:0.00184, val_loss:0.003
# epoch:90, loss:0.00198, val_loss:0.003
# epoch:91, loss:0.00171, val_loss:0.003
# epoch:92, loss:0.00205, val_loss:0.003
# epoch:93, loss:0.00165, val_loss:0.003
# epoch:94, loss:0.00182, val_loss:0.002
# epoch:95, loss:0.00169, val_loss:0.003
# epoch:96, loss:0.00192, val_loss:0.003
# epoch:97, loss:0.00162, val_loss:0.002
# epoch:98, loss:0.00182, val_loss:0.002
# epoch:99, loss:0.00157, val_loss:0.002
# epoch:100, loss:0.00158, val_loss:0.002
# epoch:101, loss:0.00147, val_loss:0.002
# epoch:102, loss:0.00145, val_loss:0.002
# epoch:103, loss:0.00155, val_loss:0.002
# epoch:104, loss:0.0014, val_loss:0.002
# epoch:105, loss:0.00149, val_loss:0.002
# epoch:106, loss:0.00154, val_loss:0.002
# epoch:107, loss:0.00148, val_loss:0.002
# epoch:108, loss:0.00145, val_loss:0.002
# epoch:109, loss:0.0014, val_loss:0.002
# epoch:110, loss:0.00151, val_loss:0.002
# epoch:111, loss:0.00148, val_loss:0.002
# epoch:112, loss:0.00142, val_loss:0.002
# epoch:113, loss:0.00143, val_loss:0.002
# epoch:114, loss:0.00149, val_loss:0.002
# epoch:115, loss:0.00133, val_loss:0.002
# epoch:116, loss:0.00132, val_loss:0.002
# epoch:117, loss:0.00136, val_loss:0.002
# epoch:118, loss:0.00125, val_loss:0.002
# epoch:119, loss:0.00136, val_loss:0.002
# epoch:120, loss:0.00134, val_loss:0.002
# epoch:121, loss:0.00126, val_loss:0.002
# epoch:122, loss:0.00133, val_loss:0.002
# epoch:123, loss:0.0012, val_loss:0.002
# epoch:124, loss:0.00136, val_loss:0.002
# epoch:125, loss:0.00119, val_loss:0.002
# epoch:126, loss:0.00121, val_loss:0.002
# epoch:127, loss:0.0013, val_loss:0.002
# epoch:128, loss:0.00127, val_loss:0.002
# epoch:129, loss:0.00116, val_loss:0.002
# epoch:130, loss:0.00122, val_loss:0.002
# epoch:131, loss:0.00135, val_loss:0.002
# epoch:132, loss:0.00119, val_loss:0.002
# epoch:133, loss:0.00123, val_loss:0.002
# epoch:134, loss:0.00122, val_loss:0.002
# epoch:135, loss:0.0012, val_loss:0.002
# epoch:136, loss:0.0012, val_loss:0.002
# epoch:137, loss:0.00116, val_loss:0.002
# epoch:138, loss:0.00114, val_loss:0.002
# epoch:139, loss:0.00116, val_loss:0.002
# epoch:140, loss:0.00109, val_loss:0.001
# epoch:141, loss:0.00111, val_loss:0.002
# epoch:142, loss:0.0011, val_loss:0.001
# epoch:143, loss:0.00112, val_loss:0.001
# epoch:144, loss:0.00112, val_loss:0.001
# epoch:145, loss:0.00107, val_loss:0.001
# epoch:146, loss:0.00121, val_loss:0.001
# epoch:147, loss:0.00111, val_loss:0.001
# epoch:148, loss:0.00111, val_loss:0.001
# epoch:149, loss:0.00106, val_loss:0.001
# epoch:150, loss:0.00119, val_loss:0.001
# epoch:151, loss:0.0011, val_loss:0.001
# epoch:152, loss:0.00106, val_loss:0.001
# epoch:153, loss:0.00102, val_loss:0.001
# epoch:154, loss:0.00102, val_loss:0.001
# epoch:155, loss:0.000995, val_loss:0.001
# epoch:156, loss:0.00109, val_loss:0.001
# epoch:157, loss:0.00105, val_loss:0.001
# epoch:158, loss:0.00111, val_loss:0.001
# epoch:159, loss:0.0011, val_loss:0.001
# epoch:160, loss:0.00102, val_loss:0.001
# epoch:161, loss:0.00118, val_loss:0.001
# epoch:162, loss:0.00104, val_loss:0.001
# epoch:163, loss:0.00106, val_loss:0.001
# epoch:164, loss:0.000949, val_loss:0.001
# epoch:165, loss:0.00108, val_loss:0.001
# epoch:166, loss:0.000947, val_loss:0.001
# epoch:167, loss:0.00105, val_loss:0.001
# epoch:168, loss:0.00106, val_loss:0.001
# epoch:169, loss:0.000937, val_loss:0.001
# epoch:170, loss:0.00104, val_loss:0.001
# epoch:171, loss:0.000996, val_loss:0.001
# epoch:172, loss:0.000944, val_loss:0.001
# epoch:173, loss:0.000968, val_loss:0.001
# epoch:174, loss:0.00106, val_loss:0.001
# epoch:175, loss:0.000994, val_loss:0.001
# epoch:176, loss:0.000974, val_loss:0.001
# epoch:177, loss:0.000957, val_loss:0.001
# epoch:178, loss:0.00101, val_loss:0.001
# epoch:179, loss:0.000957, val_loss:0.001
# epoch:180, loss:0.00102, val_loss:0.001
# epoch:181, loss:0.00101, val_loss:0.001
# epoch:182, loss:0.000977, val_loss:0.001
# epoch:183, loss:0.00102, val_loss:0.001
# epoch:184, loss:0.00101, val_loss:0.001
# epoch:185, loss:0.000988, val_loss:0.001
# epoch:186, loss:0.001, val_loss:0.001
# epoch:187, loss:0.00105, val_loss:0.001
# epoch:188, loss:0.000998, val_loss:0.001
# epoch:189, loss:0.00105, val_loss:0.001
# epoch:190, loss:0.00105, val_loss:0.001
# epoch:191, loss:0.00104, val_loss:0.001
# epoch:192, loss:0.000916, val_loss:0.001
# epoch:193, loss:0.000932, val_loss:0.001
# epoch:194, loss:0.000994, val_loss:0.001
# epoch:195, loss:0.000972, val_loss:0.001
# epoch:196, loss:0.000917, val_loss:0.001
# epoch:197, loss:0.000994, val_loss:0.001
# epoch:198, loss:0.000961, val_loss:0.001
# epoch:199, loss:0.000948, val_loss:0.001
# epoch:200, loss:0.000969, val_loss:0.001
# epoch:201, loss:0.000954, val_loss:0.001
# epoch:202, loss:0.000906, val_loss:0.001
# epoch:203, loss:0.000919, val_loss:0.001
# epoch:204, loss:0.000933, val_loss:0.001
# epoch:205, loss:0.000951, val_loss:0.001
# epoch:206, loss:0.000904, val_loss:0.001
# epoch:207, loss:0.000922, val_loss:0.001
# epoch:208, loss:0.000943, val_loss:0.001
# epoch:209, loss:0.00097, val_loss:0.001
# epoch:210, loss:0.00098, val_loss:0.001
# epoch:211, loss:0.000916, val_loss:0.001
# epoch:212, loss:0.000946, val_loss:0.001
# epoch:213, loss:0.000963, val_loss:0.001
# epoch:214, loss:0.000936, val_loss:0.001
# epoch:215, loss:0.000941, val_loss:0.001
# epoch:216, loss:0.000961, val_loss:0.001
# epoch:217, loss:0.000902, val_loss:0.001
# epoch:218, loss:0.00101, val_loss:0.001
# epoch:219, loss:0.000923, val_loss:0.001
# epoch:220, loss:0.000926, val_loss:0.001
# epoch:221, loss:0.000954, val_loss:0.001
# epoch:222, loss:0.000899, val_loss:0.001
# epoch:223, loss:0.000916, val_loss:0.001
# epoch:224, loss:0.00101, val_loss:0.001
# epoch:225, loss:0.000836, val_loss:0.001
# epoch:226, loss:0.00092, val_loss:0.001
# epoch:227, loss:0.000897, val_loss:0.001
# epoch:228, loss:0.000886, val_loss:0.001
# epoch:229, loss:0.000988, val_loss:0.001
# epoch:230, loss:0.00095, val_loss:0.001
# epoch:231, loss:0.000954, val_loss:0.001
# epoch:232, loss:0.000959, val_loss:0.001
# epoch:233, loss:0.000925, val_loss:0.001
# epoch:234, loss:0.00104, val_loss:0.001
# epoch:235, loss:0.000934, val_loss:0.001
# epoch:236, loss:0.000893, val_loss:0.001
# epoch:237, loss:0.001, val_loss:0.001
# epoch:238, loss:0.000964, val_loss:0.001
# epoch:239, loss:0.000963, val_loss:0.001
# epoch:240, loss:0.000939, val_loss:0.001
# epoch:241, loss:0.00101, val_loss:0.001
# epoch:242, loss:0.000973, val_loss:0.001
# epoch:243, loss:0.000977, val_loss:0.001
# epoch:244, loss:0.000904, val_loss:0.001
# epoch:245, loss:0.000999, val_loss:0.001
# epoch:246, loss:0.00095, val_loss:0.001
# epoch:247, loss:0.000858, val_loss:0.001
# epoch:248, loss:0.000952, val_loss:0.001
# epoch:249, loss:0.000998, val_loss:0.001
# epoch:250, loss:0.000886, val_loss:0.001
# epoch:251, loss:0.00103, val_loss:0.001
# epoch:252, loss:0.000933, val_loss:0.001
# epoch:253, loss:0.00104, val_loss:0.001
# epoch:254, loss:0.000898, val_loss:0.001
# epoch:255, loss:0.001, val_loss:0.001
# epoch:256, loss:0.000986, val_loss:0.001
# early stopping

# %%
fig = plt.figure()
plt.plot(gen, '.', label = 'prediction')
plt.plot(sin_wave, '.', alpha = 0.5,label =  'sin')
plt.legend()
